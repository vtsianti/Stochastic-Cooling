# %%
import numpy as np
import matplotlib.pyplot as plt

def respL(Dt):
    return (63e9 * Dt) * (1 - 6.5e18 * Dt**2) * (1 - 1.55e18 * Dt**2) * (1 - (0.625e9 * Dt)**2) ** 8

# Define parameters
Th = 1e-9  # Example value for Th
x_vals = np.linspace(-2 * Th, 2 * Th, 400)
y_vals = respL(x_vals)

# Create plot
fig, ax = plt.subplots()
colors = ['red', 'blue', 'green', 'purple']
labels = ["1st group 1st square", "2nd group 2nd square", "3rd group 3rd square", "4th group 4th square"]

for i in range(4):
    x_start = (i - 2) * Th  # -Th, 0, Th, 2Th
    rect = plt.Rectangle((x_start, min(y_vals)), Th, max(y_vals) - min(y_vals), color=colors[i], alpha=0.3, label=labels[i])
    ax.add_patch(rect)

# Plot the function
ax.plot(x_vals, y_vals, 'k-', label="respL(Dt)")

# Formatting
ax.axhline(0, color='black', linewidth=0.5)
ax.axvline(0, color='black', linewidth=0.5)
ax.legend()
ax.set_xlabel("Dt")
ax.set_ylabel("respL(Dt)")
ax.set_title("Function Plot with Square Groups")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def respL(Dt):
    return (63e9 * Dt) * (1 - 6.5e18 * Dt**2) * (1 - 1.55e18 * Dt**2) * (1 - (0.625e9 * Dt)**2) ** 8

# Define parameters
Th = 1e-6  # Example value for Th
wlL, wrL = -1.6e-9, 1.6e-9  # Limits
x_vals = np.linspace(wlL, wrL, 400)
y_vals = respL(x_vals)

# Create plot
fig, ax = plt.subplots()
colors = ['red', 'blue', 'green', 'purple']
labels = ["1st group 1st square", "2nd group 2nd square", "3rd group 3rd square", "4th group 4th square"]

for i in range(4):
    x_start = (i - 2) * Th  # -2Th, -Th, 0, Th
    rect = plt.Rectangle((x_start, min(y_vals)), Th, max(y_vals) - min(y_vals), color=colors[i], alpha=0.3, label=labels[i])
    ax.add_patch(rect)

# Plot the functions between squares
for i in range(3):
    x_func = np.linspace((i - 1.5) * Th, (i - 0.5) * Th, 100)
    ax.plot(x_func, respL(x_func), 'k-', label=f"Function {i+1}")

# Formatting
ax.axhline(0, color='black', linewidth=0.5)
ax.axvline(0, color='black', linewidth=0.5)
ax.set_xticks([-2*Th, -Th, 0, Th, 2*Th])
ax.set_xticklabels(["-2Th", "-Th", "0", "Th", "2Th"])
ax.legend()
ax.set_xlabel("Dt")
ax.set_ylabel("respL(Dt)")
ax.set_title("Function Plot with Square Groups")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def respL(Dt):
    return (63e9 * Dt) * (1 - 6.5e18 * Dt**2) * (1 - 1.55e18 * Dt**2) * (1 - (0.625e9 * Dt)**2) ** 8

# Define parameters
Th = 1e-9  # Example value for Th
wlL, wrL = -1.6e-9, 1.6e-9  # Limits
x_vals = np.linspace(wlL, wrL, 400)
y_vals = respL(x_vals)

# Create plot
fig, ax = plt.subplots()
colors = ['red', 'blue', 'green', 'purple']
labels = ["1st group 1st square", "2nd group 2nd square", "3rd group 3rd square", "4th group 4th square"]

for i in range(4):
    x_start = (i - 2) * Th  # -2Th, -Th, 0, Th
    rect = plt.Rectangle((x_start, min(y_vals)), Th, max(y_vals) - min(y_vals), color=colors[i], alpha=0.3, label=labels[i])
    ax.add_patch(rect)

# Plot the functions between all squares
for i in range(3):
    x_func = np.linspace((i - 1.5) * Th, (i - 0.5) * Th, 100)
    ax.plot(x_func, respL(x_func - (i - 1) * Th), 'k-', label=f"Function {i+1}")

# Formatting
ax.axhline(0, color='black', linewidth=0.5)
ax.axvline(0, color='black', linewidth=0.5)
ax.set_xticks([-2*Th, -Th, 0, Th, 2*Th])
ax.set_xticklabels(["-2Th", "-Th", "0", "Th", "2Th"])
ax.legend()
ax.set_xlabel("Dt")
ax.set_ylabel("respL(Dt)")
ax.set_title("Function Plot with Square Groups")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def respL(Dt):
    return (63e9 * Dt) * (1 - 6.5e18 * Dt**2) * (1 - 1.55e18 * Dt**2) * (1 - (0.625e9 * Dt)**2) ** 8

# Define parameters
Th = 1e-9  # Example value for Th
wlL, wrL = -1.6e-9, 1.6e-9  # Limits
x_vals = np.linspace(wlL, wrL, 400)
y_vals = respL(x_vals)

# Create plot
fig, ax = plt.subplots()
colors = ['red', 'blue', 'red', 'blue','red']
labels = ["1st early group", "1st late group ", "2nd early group", "2nd late group", '3rd early group']
line_styles = ['-', '--', '-.', ':']  # Different line styles for each signal

for i in range(5):
    x_start = (i - 2) * Th  # -2Th, -Th, 0, Th
    rect = plt.Rectangle((x_start, min(y_vals)), Th, max(y_vals) - min(y_vals), color=colors[i], alpha=0.3, label=labels[i])
    ax.add_patch(rect)

# Plot the functions between all squares
for i in range(3):
    x_func = np.linspace((i - 1.5) * Th, (i - 0.5) * Th, 100)
    ax.plot(x_func, respL(x_func - (i - 1) * Th), line_styles[i], label=f"Signal {i+1}")

# Formatting
ax.axhline(0, color='black', linewidth=0.5)
ax.axvline(0, color='black', linewidth=0.5)
ax.set_xticks([-2*Th, -Th, 0, Th, 2*Th, 3*Th])
ax.set_xticklabels(["-2Th", "-Th", "0", "Th", "2Th", "..."])
ax.legend(loc='upper left', bbox_to_anchor=(1, 1))  # Move legend outside the plot
ax.set_xlabel("Dt")
ax.set_ylabel("")
ax.set_title("Function Plot with Groups")

plt.show()
